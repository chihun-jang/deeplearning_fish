# %%
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt


N = 2   # 미니배치 크기
H = 3   # 은닉 상태 벡터의 차원 수
T = 20  # 시계열 데이터의 길이

dh = np.ones((N, H))

np.random.seed(3) # 재현할 수 있도록 난수의 시드 고정

Wh = np.random.randn(H, H)
#Wh = np.random.randn(H, H) * 0.5

norm_list = []
for t in range(T):
    dh = np.dot(dh, Wh.T)
    norm = np.sqrt(np.sum(dh**2)) / N
    norm_list.append(norm)

print(norm_list)

# 그래프 그리기
plt.plot(np.arange(len(norm_list)), norm_list)
plt.xticks([0, 4, 9, 14, 19], [1, 5, 10, 15, 20])
plt.xlabel('시간 크기(time step)')
plt.ylabel('노름(norm)')
plt.show()
# Out:
# [2.4684068094579303, 3.335704974161037, 4.783279375373183, 6.2795873320876145, 8.080776465019055, 10.25116303229294, 12.9360635066099, 16.276861327786712, 20.454829618345983, 25.688972842084684, 32.25315718048336, 40.48895641683869, 50.824407307019094, 63.79612654485427, 80.07737014308985, 100.51298922051251, 126.16331847536827, 158.3592064825883, 198.77107967611957, 249.495615421267]

# %%
N = 2   # 미니배치 크기
H = 3   # 은닉 상태 벡터의 차원 수
T = 20  # 시계열 데이터의 길이

dh = np.ones((N, H))

np.random.seed(3) # 재현할 수 있도록 난수의 시드 고정

# Wh = np.random.randn(H, H)
Wh = np.random.randn(H, H) * 0.5

norm_list = []
for t in range(T):
    dh = np.dot(dh, Wh.T)
    norm = np.sqrt(np.sum(dh**2)) / N
    norm_list.append(norm)

print(norm_list)

# 그래프 그리기
plt.plot(np.arange(len(norm_list)), norm_list)
plt.xticks([0, 4, 9, 14, 19], [1, 5, 10, 15, 20])
plt.xlabel('시간 크기(time step)')
plt.ylabel('노름(norm)')
plt.show()
# Out:
# [1.2342034047289652, 0.8339262435402592, 0.5979099219216478, 0.3924742082554759, 0.25252426453184545, 0.16017442237957719, 0.10106299614538984, 0.06358148956166684, 0.039950839098332, 0.025086887541098325, 0.015748611904532892, 0.009884999125204758, 0.006204151282595104, 0.003893806551809953, 0.002443767399386287, 0.0015337065005571367, 0.0009625497320203268, 0.0006040924319556743, 0.00037912574706291117, 0.00023793756048323344]

# %%
# coding: utf-8


dW1 = np.random.rand(3, 3) * 10
dW2 = np.random.rand(3, 3) * 10
grads = [dW1, dW2]
max_norm = 5.0


def clip_grads(grads, max_norm):
    total_norm = 0
    for grad in grads:
        total_norm += np.sum(grad ** 2)
    total_norm = np.sqrt(total_norm)

    rate = max_norm / (total_norm + 1e-6)
    if rate < 1:
        for grad in grads:
            grad *= rate


print('before:', dW1.flatten())
clip_grads(grads, max_norm)
print('after:', dW1.flatten())
# Out:
# before: [6.49144048 2.78487283 6.76254902 5.90862817 0.23981882 5.58854088
#  2.59252447 4.15101197 2.83525082]
# after: [1.49503731 0.64138134 1.55747605 1.36081038 0.05523244 1.28709139
#  0.59708178 0.95601551 0.65298384]

# %%
# coding: utf-8
import sys
sys.path.append('..')
from common.time_layers import *
from common.base_model import BaseModel


class Rnnlm(BaseModel):
    def __init__(self, vocab_size=10000, wordvec_size=100, hidden_size=100):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        # 가중치 초기화
        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        # 계층 생성
        self.layers = [
            TimeEmbedding(embed_W),
            TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True),
            TimeAffine(affine_W, affine_b)
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layer = self.layers[1]

        # 모든 가중치와 기울기를 리스트에 모은다.
        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def predict(self, xs):
        for layer in self.layers:
            xs = layer.forward(xs)
        return xs

    def forward(self, xs, ts):
        score = self.predict(xs)
        loss = self.loss_layer.forward(score, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        self.lstm_layer.reset_state()

# %%
# coding: utf-8
import sys
sys.path.append('..')
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity
from dataset import ptb


# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 100
hidden_size = 100  # RNN의 은닉 상태 벡터의 원소 수
time_size = 35     # RNN을 펼치는 크기
lr = 20.0
max_epoch = 4
max_grad = 0.25

# 학습 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test, _, _ = ptb.load_data('test')
vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

# 모델 생성
model = Rnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

# 기울기 클리핑을 적용하여 학습
trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad,
            eval_interval=20)
# 기울기를 구해서 모델 매개변수 갱신,
# max_grad로 기울기 클리핑적용
#eval_interval=20은 20번째 반복마다 퍼플렉서티를 평가하라는 뜻이다.

trainer.plot(ylim=(0, 500)) #그래프 그리기

# 테스트 데이터로 평가
model.reset_state()  # 모델의 상태(은닉상태와 기억셀)를 재설정해서 평가한다.
ppl_test = eval_perplexity(model, corpus_test)
print('테스트 퍼플렉서티: ', ppl_test)

# 매개변수 저장
model.save_params() # 학습이 완료된 매개변수를 저장한다.
# Out:
# Downloading ptb.test.txt ...
# Done
# | 에폭 1 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 9997.84
# | 에폭 1 |  반복 21 / 1327 | 시간 11[s] | 퍼플렉서티 3219.22
# | 에폭 1 |  반복 41 / 1327 | 시간 22[s] | 퍼플렉서티 1232.75
# | 에폭 1 |  반복 61 / 1327 | 시간 33[s] | 퍼플렉서티 999.85
# | 에폭 1 |  반복 81 / 1327 | 시간 44[s] | 퍼플렉서티 812.34
# | 에폭 1 |  반복 101 / 1327 | 시간 55[s] | 퍼플렉서티 658.54
# | 에폭 1 |  반복 121 / 1327 | 시간 66[s] | 퍼플렉서티 667.43
# | 에폭 1 |  반복 141 / 1327 | 시간 76[s] | 퍼플렉서티 602.08
# | 에폭 1 |  반복 161 / 1327 | 시간 87[s] | 퍼플렉서티 592.13
# | 에폭 1 |  반복 181 / 1327 | 시간 97[s] | 퍼플렉서티 596.22
# | 에폭 1 |  반복 201 / 1327 | 시간 108[s] | 퍼플렉서티 506.09
# | 에폭 1 |  반복 221 / 1327 | 시간 119[s] | 퍼플렉서티 494.46
# | 에폭 1 |  반복 241 / 1327 | 시간 130[s] | 퍼플렉서티 445.55
# | 에폭 1 |  반복 261 / 1327 | 시간 140[s] | 퍼플렉서티 465.24
# | 에폭 1 |  반복 281 / 1327 | 시간 152[s] | 퍼플렉서티 452.53
# | 에폭 1 |  반복 301 / 1327 | 시간 163[s] | 퍼플렉서티 389.17
# | 에폭 1 |  반복 321 / 1327 | 시간 173[s] | 퍼플렉서티 342.53
# | 에폭 1 |  반복 341 / 1327 | 시간 184[s] | 퍼플렉서티 406.86
# | 에폭 1 |  반복 361 / 1327 | 시간 195[s] | 퍼플렉서티 410.31
# | 에폭 1 |  반복 381 / 1327 | 시간 206[s] | 퍼플렉서티 337.42
# | 에폭 1 |  반복 401 / 1327 | 시간 218[s] | 퍼플렉서티 348.36
# | 에폭 1 |  반복 421 / 1327 | 시간 229[s] | 퍼플렉서티 345.50
# | 에폭 1 |  반복 441 / 1327 | 시간 240[s] | 퍼플렉서티 329.37
# | 에폭 1 |  반복 461 / 1327 | 시간 252[s] | 퍼플렉서티 327.83
# | 에폭 1 |  반복 481 / 1327 | 시간 263[s] | 퍼플렉서티 307.48
# | 에폭 1 |  반복 501 / 1327 | 시간 274[s] | 퍼플렉서티 315.85
# | 에폭 1 |  반복 521 / 1327 | 시간 285[s] | 퍼플렉서티 302.05
# | 에폭 1 |  반복 541 / 1327 | 시간 295[s] | 퍼플렉서티 321.80
# | 에폭 1 |  반복 561 / 1327 | 시간 306[s] | 퍼플렉서티 286.30
# | 에폭 1 |  반복 581 / 1327 | 시간 318[s] | 퍼플렉서티 257.66
# | 에폭 1 |  반복 601 / 1327 | 시간 330[s] | 퍼플렉서티 338.93
# | 에폭 1 |  반복 621 / 1327 | 시간 341[s] | 퍼플렉서티 311.39
# | 에폭 1 |  반복 641 / 1327 | 시간 353[s] | 퍼플렉서티 286.46
# | 에폭 1 |  반복 661 / 1327 | 시간 364[s] | 퍼플렉서티 267.63
# | 에폭 1 |  반복 681 / 1327 | 시간 375[s] | 퍼플렉서티 227.29
# | 에폭 1 |  반복 701 / 1327 | 시간 386[s] | 퍼플렉서티 252.51
# | 에폭 1 |  반복 721 / 1327 | 시간 398[s] | 퍼플렉서티 262.76
# | 에폭 1 |  반복 741 / 1327 | 시간 409[s] | 퍼플렉서티 220.63
# | 에폭 1 |  반복 761 / 1327 | 시간 421[s] | 퍼플렉서티 231.95
# | 에폭 1 |  반복 781 / 1327 | 시간 433[s] | 퍼플렉서티 220.43
# | 에폭 1 |  반복 801 / 1327 | 시간 444[s] | 퍼플렉서티 244.74
# | 에폭 1 |  반복 821 / 1327 | 시간 455[s] | 퍼플렉서티 226.17
# | 에폭 1 |  반복 841 / 1327 | 시간 465[s] | 퍼플렉서티 229.78
# | 에폭 1 |  반복 861 / 1327 | 시간 476[s] | 퍼플렉서티 224.57
# | 에폭 1 |  반복 881 / 1327 | 시간 487[s] | 퍼플렉서티 206.89
# | 에폭 1 |  반복 901 / 1327 | 시간 498[s] | 퍼플렉서티 255.33
# | 에폭 1 |  반복 921 / 1327 | 시간 509[s] | 퍼플렉서티 228.00
# | 에폭 1 |  반복 941 / 1327 | 시간 520[s] | 퍼플렉서티 231.89
# | 에폭 1 |  반복 961 / 1327 | 시간 531[s] | 퍼플렉서티 246.23
# | 에폭 1 |  반복 981 / 1327 | 시간 7040[s] | 퍼플렉서티 231.55
# | 에폭 1 |  반복 1001 / 1327 | 시간 7062[s] | 퍼플렉서티 193.73
# | 에폭 1 |  반복 1021 / 1327 | 시간 7075[s] | 퍼플렉서티 227.50
# | 에폭 1 |  반복 1041 / 1327 | 시간 7086[s] | 퍼플렉서티 208.59
# | 에폭 1 |  반복 1061 / 1327 | 시간 7096[s] | 퍼플렉서티 196.79
# | 에폭 1 |  반복 1081 / 1327 | 시간 7107[s] | 퍼플렉서티 170.82
# | 에폭 1 |  반복 1101 / 1327 | 시간 7118[s] | 퍼플렉서티 194.28
# | 에폭 1 |  반복 1121 / 1327 | 시간 7132[s] | 퍼플렉서티 228.07
# | 에폭 1 |  반복 1141 / 1327 | 시간 7151[s] | 퍼플렉서티 208.64
# | 에폭 1 |  반복 1161 / 1327 | 시간 7161[s] | 퍼플렉서티 200.11
# | 에폭 1 |  반복 1181 / 1327 | 시간 8950[s] | 퍼플렉서티 193.29
# | 에폭 1 |  반복 1201 / 1327 | 시간 12410[s] | 퍼플렉서티 164.23
# | 에폭 1 |  반복 1221 / 1327 | 시간 12430[s] | 퍼플렉서티 160.91
# | 에폭 1 |  반복 1241 / 1327 | 시간 12441[s] | 퍼플렉서티 188.80
# | 에폭 1 |  반복 1261 / 1327 | 시간 12452[s] | 퍼플렉서티 173.57
# | 에폭 1 |  반복 1281 / 1327 | 시간 12462[s] | 퍼플렉서티 178.85
# | 에폭 1 |  반복 1301 / 1327 | 시간 12472[s] | 퍼플렉서티 224.33
# | 에폭 1 |  반복 1321 / 1327 | 시간 12483[s] | 퍼플렉서티 212.38
# | 에폭 2 |  반복 1 / 1327 | 시간 12486[s] | 퍼플렉서티 225.75
# | 에폭 2 |  반복 21 / 1327 | 시간 12496[s] | 퍼플렉서티 204.37
# | 에폭 2 |  반복 41 / 1327 | 시간 12507[s] | 퍼플렉서티 191.02
# | 에폭 2 |  반복 61 / 1327 | 시간 12517[s] | 퍼플렉서티 178.06
# | 에폭 2 |  반복 81 / 1327 | 시간 12527[s] | 퍼플렉서티 159.69
# | 에폭 2 |  반복 101 / 1327 | 시간 12537[s] | 퍼플렉서티 155.12
# | 에폭 2 |  반복 121 / 1327 | 시간 12548[s] | 퍼플렉서티 161.59
# | 에폭 2 |  반복 141 / 1327 | 시간 12564[s] | 퍼플렉서티 179.23
# | 에폭 2 |  반복 161 / 1327 | 시간 12576[s] | 퍼플렉서티 193.60
# | 에폭 2 |  반복 181 / 1327 | 시간 12588[s] | 퍼플렉서티 202.50
# | 에폭 2 |  반복 201 / 1327 | 시간 12600[s] | 퍼플렉서티 187.78
# | 에폭 2 |  반복 221 / 1327 | 시간 12612[s] | 퍼플렉서티 185.65
# | 에폭 2 |  반복 241 / 1327 | 시간 12623[s] | 퍼플렉서티 177.65
# | 에폭 2 |  반복 261 / 1327 | 시간 12635[s] | 퍼플렉서티 185.35
# | 에폭 2 |  반복 281 / 1327 | 시간 12645[s] | 퍼플렉서티 188.73
# | 에폭 2 |  반복 301 / 1327 | 시간 12655[s] | 퍼플렉서티 168.20
# | 에폭 2 |  반복 321 / 1327 | 시간 12666[s] | 퍼플렉서티 140.12
# | 에폭 2 |  반복 341 / 1327 | 시간 12676[s] | 퍼플렉서티 173.88
# | 에폭 2 |  반복 361 / 1327 | 시간 12686[s] | 퍼플렉서티 199.71
# | 에폭 2 |  반복 381 / 1327 | 시간 12697[s] | 퍼플렉서티 155.88
# | 에폭 2 |  반복 401 / 1327 | 시간 12707[s] | 퍼플렉서티 170.41
# | 에폭 2 |  반복 421 / 1327 | 시간 12717[s] | 퍼플렉서티 157.37
# | 에폭 2 |  반복 441 / 1327 | 시간 12728[s] | 퍼플렉서티 164.67
# | 에폭 2 |  반복 461 / 1327 | 시간 12738[s] | 퍼플렉서티 158.10
# | 에폭 2 |  반복 481 / 1327 | 시간 12748[s] | 퍼플렉서티 158.15
# | 에폭 2 |  반복 501 / 1327 | 시간 12758[s] | 퍼플렉서티 171.18
# | 에폭 2 |  반복 521 / 1327 | 시간 12769[s] | 퍼플렉서티 173.55
# | 에폭 2 |  반복 541 / 1327 | 시간 12779[s] | 퍼플렉서티 174.95
# | 에폭 2 |  반복 561 / 1327 | 시간 12789[s] | 퍼플렉서티 155.59
# | 에폭 2 |  반복 581 / 1327 | 시간 12800[s] | 퍼플렉서티 139.88
# | 에폭 2 |  반복 601 / 1327 | 시간 12810[s] | 퍼플렉서티 192.13
# | 에폭 2 |  반복 621 / 1327 | 시간 12820[s] | 퍼플렉서티 186.14
# | 에폭 2 |  반복 641 / 1327 | 시간 12831[s] | 퍼플렉서티 165.06
# | 에폭 2 |  반복 661 / 1327 | 시간 12842[s] | 퍼플렉서티 155.94
# | 에폭 2 |  반복 681 / 1327 | 시간 12853[s] | 퍼플렉서티 130.08
# | 에폭 2 |  반복 701 / 1327 | 시간 12864[s] | 퍼플렉서티 154.07
# | 에폭 2 |  반복 721 / 1327 | 시간 12874[s] | 퍼플렉서티 161.35
# | 에폭 2 |  반복 741 / 1327 | 시간 12884[s] | 퍼플렉서티 134.89
# | 에폭 2 |  반복 761 / 1327 | 시간 12894[s] | 퍼플렉서티 130.93
# | 에폭 2 |  반복 781 / 1327 | 시간 12904[s] | 퍼플렉서티 134.47
# | 에폭 2 |  반복 801 / 1327 | 시간 12915[s] | 퍼플렉서티 148.96
# | 에폭 2 |  반복 821 / 1327 | 시간 12925[s] | 퍼플렉서티 145.38
# | 에폭 2 |  반복 841 / 1327 | 시간 12936[s] | 퍼플렉서티 145.75
# | 에폭 2 |  반복 861 / 1327 | 시간 12946[s] | 퍼플렉서티 146.96
# | 에폭 2 |  반복 881 / 1327 | 시간 12957[s] | 퍼플렉서티 131.75
# | 에폭 2 |  반복 901 / 1327 | 시간 12968[s] | 퍼플렉서티 167.11
# | 에폭 2 |  반복 921 / 1327 | 시간 12979[s] | 퍼플렉서티 148.31
# | 에폭 2 |  반복 941 / 1327 | 시간 12989[s] | 퍼플렉서티 154.48
# | 에폭 2 |  반복 961 / 1327 | 시간 13000[s] | 퍼플렉서티 165.37
# | 에폭 2 |  반복 981 / 1327 | 시간 13010[s] | 퍼플렉서티 155.76
# | 에폭 2 |  반복 1001 / 1327 | 시간 13020[s] | 퍼플렉서티 133.16
# | 에폭 2 |  반복 1021 / 1327 | 시간 13031[s] | 퍼플렉서티 158.40
# | 에폭 2 |  반복 1041 / 1327 | 시간 13043[s] | 퍼플렉서티 142.96
# | 에폭 2 |  반복 1061 / 1327 | 시간 13055[s] | 퍼플렉서티 129.11
# | 에폭 2 |  반복 1081 / 1327 | 시간 13066[s] | 퍼플렉서티 112.08
# | 에폭 2 |  반복 1101 / 1327 | 시간 13077[s] | 퍼플렉서티 121.52
# | 에폭 2 |  반복 1121 / 1327 | 시간 13089[s] | 퍼플렉서티 155.52
# | 에폭 2 |  반복 1141 / 1327 | 시간 13101[s] | 퍼플렉서티 142.67
# | 에폭 2 |  반복 1161 / 1327 | 시간 13113[s] | 퍼플렉서티 133.59
# | 에폭 2 |  반복 1181 / 1327 | 시간 13125[s] | 퍼플렉서티 135.30
# | 에폭 2 |  반복 1201 / 1327 | 시간 13137[s] | 퍼플렉서티 113.02
# | 에폭 2 |  반복 1221 / 1327 | 시간 13149[s] | 퍼플렉서티 110.75
# | 에폭 2 |  반복 1241 / 1327 | 시간 13160[s] | 퍼플렉서티 131.85
# | 에폭 2 |  반복 1261 / 1327 | 시간 13171[s] | 퍼플렉서티 124.17
# | 에폭 2 |  반복 1281 / 1327 | 시간 13183[s] | 퍼플렉서티 123.13
# | 에폭 2 |  반복 1301 / 1327 | 시간 13195[s] | 퍼플렉서티 159.58
# | 에폭 2 |  반복 1321 / 1327 | 시간 13206[s] | 퍼플렉서티 153.43
# | 에폭 3 |  반복 1 / 1327 | 시간 13209[s] | 퍼플렉서티 162.71
# | 에폭 3 |  반복 21 / 1327 | 시간 13220[s] | 퍼플렉서티 144.78
# | 에폭 3 |  반복 41 / 1327 | 시간 13231[s] | 퍼플렉서티 136.29
# | 에폭 3 |  반복 61 / 1327 | 시간 13241[s] | 퍼플렉서티 127.84
# | 에폭 3 |  반복 81 / 1327 | 시간 13252[s] | 퍼플렉서티 117.02
# | 에폭 3 |  반복 101 / 1327 | 시간 13263[s] | 퍼플렉서티 106.83
# | 에폭 3 |  반복 121 / 1327 | 시간 13274[s] | 퍼플렉서티 117.05
# | 에폭 3 |  반복 141 / 1327 | 시간 13285[s] | 퍼플렉서티 126.22
# | 에폭 3 |  반복 161 / 1327 | 시간 13295[s] | 퍼플렉서티 142.15
# | 에폭 3 |  반복 181 / 1327 | 시간 13306[s] | 퍼플렉서티 152.29
# | 에폭 3 |  반복 201 / 1327 | 시간 13317[s] | 퍼플렉서티 142.13
# | 에폭 3 |  반복 221 / 1327 | 시간 13327[s] | 퍼플렉서티 143.35
# | 에폭 3 |  반복 241 / 1327 | 시간 13338[s] | 퍼플렉서티 135.49
# | 에폭 3 |  반복 261 / 1327 | 시간 13349[s] | 퍼플렉서티 139.39
# | 에폭 3 |  반복 281 / 1327 | 시간 13360[s] | 퍼플렉서티 142.19
# | 에폭 3 |  반복 301 / 1327 | 시간 13370[s] | 퍼플렉서티 124.26
# | 에폭 3 |  반복 321 / 1327 | 시간 13381[s] | 퍼플렉서티 102.76
# | 에폭 3 |  반복 341 / 1327 | 시간 13392[s] | 퍼플렉서티 125.07
# | 에폭 3 |  반복 361 / 1327 | 시간 13403[s] | 퍼플렉서티 153.90
# | 에폭 3 |  반복 381 / 1327 | 시간 13414[s] | 퍼플렉서티 115.70
# | 에폭 3 |  반복 401 / 1327 | 시간 13425[s] | 퍼플렉서티 130.97
# | 에폭 3 |  반복 421 / 1327 | 시간 13435[s] | 퍼플렉서티 116.25
# | 에폭 3 |  반복 441 / 1327 | 시간 13447[s] | 퍼플렉서티 124.74
# | 에폭 3 |  반복 461 / 1327 | 시간 13457[s] | 퍼플렉서티 120.37
# | 에폭 3 |  반복 481 / 1327 | 시간 13468[s] | 퍼플렉서티 120.98
# | 에폭 3 |  반복 501 / 1327 | 시간 13479[s] | 퍼플렉서티 129.45
# | 에폭 3 |  반복 521 / 1327 | 시간 13489[s] | 퍼플렉서티 137.78
# | 에폭 3 |  반복 541 / 1327 | 시간 13500[s] | 퍼플렉서티 136.38
# | 에폭 3 |  반복 561 / 1327 | 시간 13511[s] | 퍼플렉서티 119.32
# | 에폭 3 |  반복 581 / 1327 | 시간 13522[s] | 퍼플렉서티 106.70
# | 에폭 3 |  반복 601 / 1327 | 시간 13533[s] | 퍼플렉서티 149.95
# | 에폭 3 |  반복 621 / 1327 | 시간 13543[s] | 퍼플렉서티 145.60
# | 에폭 3 |  반복 641 / 1327 | 시간 13554[s] | 퍼플렉서티 128.79
# | 에폭 3 |  반복 661 / 1327 | 시간 13565[s] | 퍼플렉서티 121.14
# | 에폭 3 |  반복 681 / 1327 | 시간 13576[s] | 퍼플렉서티 100.61
# | 에폭 3 |  반복 701 / 1327 | 시간 13586[s] | 퍼플렉서티 120.47
# | 에폭 3 |  반복 721 / 1327 | 시간 13597[s] | 퍼플렉서티 128.21
# | 에폭 3 |  반복 741 / 1327 | 시간 13608[s] | 퍼플렉서티 108.59
# | 에폭 3 |  반복 761 / 1327 | 시간 13619[s] | 퍼플렉서티 103.33
# | 에폭 3 |  반복 781 / 1327 | 시간 13631[s] | 퍼플렉서티 103.64
# | 에폭 3 |  반복 801 / 1327 | 시간 13642[s] | 퍼플렉서티 116.54
# | 에폭 3 |  반복 821 / 1327 | 시간 13653[s] | 퍼플렉서티 116.58
# | 에폭 3 |  반복 841 / 1327 | 시간 13664[s] | 퍼플렉서티 114.76
# | 에폭 3 |  반복 861 / 1327 | 시간 13675[s] | 퍼플렉서티 121.76
# | 에폭 3 |  반복 881 / 1327 | 시간 13686[s] | 퍼플렉서티 107.17
# | 에폭 3 |  반복 901 / 1327 | 시간 13697[s] | 퍼플렉서티 132.12
# | 에폭 3 |  반복 921 / 1327 | 시간 13708[s] | 퍼플렉서티 119.10
# | 에폭 3 |  반복 941 / 1327 | 시간 13719[s] | 퍼플렉서티 127.56
# | 에폭 3 |  반복 961 / 1327 | 시간 13731[s] | 퍼플렉서티 132.32
# | 에폭 3 |  반복 981 / 1327 | 시간 13742[s] | 퍼플렉서티 125.50
# | 에폭 3 |  반복 1001 / 1327 | 시간 13754[s] | 퍼플렉서티 110.58
# | 에폭 3 |  반복 1021 / 1327 | 시간 13765[s] | 퍼플렉서티 129.71
# | 에폭 3 |  반복 1041 / 1327 | 시간 13776[s] | 퍼플렉서티 119.12
# | 에폭 3 |  반복 1061 / 1327 | 시간 13789[s] | 퍼플렉서티 103.28
# | 에폭 3 |  반복 1081 / 1327 | 시간 13802[s] | 퍼플렉서티 89.75
# | 에폭 3 |  반복 1101 / 1327 | 시간 13813[s] | 퍼플렉서티 97.22
# | 에폭 3 |  반복 1121 / 1327 | 시간 13824[s] | 퍼플렉서티 123.90
# | 에폭 3 |  반복 1141 / 1327 | 시간 13834[s] | 퍼플렉서티 115.63
# | 에폭 3 |  반복 1161 / 1327 | 시간 13845[s] | 퍼플렉서티 106.98
# | 에폭 3 |  반복 1181 / 1327 | 시간 13856[s] | 퍼플렉서티 111.05
# | 에폭 3 |  반복 1201 / 1327 | 시간 13868[s] | 퍼플렉서티 93.12
# | 에폭 3 |  반복 1221 / 1327 | 시간 13879[s] | 퍼플렉서티 89.59
# | 에폭 3 |  반복 1241 / 1327 | 시간 13890[s] | 퍼플렉서티 107.12
# | 에폭 3 |  반복 1261 / 1327 | 시간 13902[s] | 퍼플렉서티 105.22
# | 에폭 3 |  반복 1281 / 1327 | 시간 13914[s] | 퍼플렉서티 101.33
# | 에폭 3 |  반복 1301 / 1327 | 시간 13925[s] | 퍼플렉서티 129.98
# | 에폭 3 |  반복 1321 / 1327 | 시간 13937[s] | 퍼플렉서티 126.97
# | 에폭 4 |  반복 1 / 1327 | 시간 13941[s] | 퍼플렉서티 133.31
# | 에폭 4 |  반복 21 / 1327 | 시간 13953[s] | 퍼플렉서티 122.42
# | 에폭 4 |  반복 41 / 1327 | 시간 13964[s] | 퍼플렉서티 107.13
# | 에폭 4 |  반복 61 / 1327 | 시간 13976[s] | 퍼플렉서티 107.94
# | 에폭 4 |  반복 81 / 1327 | 시간 13988[s] | 퍼플렉서티 95.95
# | 에폭 4 |  반복 101 / 1327 | 시간 14000[s] | 퍼플렉서티 87.79
# | 에폭 4 |  반복 121 / 1327 | 시간 14011[s] | 퍼플렉서티 96.97
# | 에폭 4 |  반복 141 / 1327 | 시간 14022[s] | 퍼플렉서티 103.66
# | 에폭 4 |  반복 161 / 1327 | 시간 14032[s] | 퍼플렉서티 117.43
# | 에폭 4 |  반복 181 / 1327 | 시간 14043[s] | 퍼플렉서티 129.77
# | 에폭 4 |  반복 201 / 1327 | 시간 14054[s] | 퍼플렉서티 121.66
# | 에폭 4 |  반복 221 / 1327 | 시간 14065[s] | 퍼플렉서티 122.99
# | 에폭 4 |  반복 241 / 1327 | 시간 14076[s] | 퍼플렉서티 115.70
# | 에폭 4 |  반복 261 / 1327 | 시간 14087[s] | 퍼플렉서티 115.10
# | 에폭 4 |  반복 281 / 1327 | 시간 14098[s] | 퍼플렉서티 120.94
# | 에폭 4 |  반복 301 / 1327 | 시간 14109[s] | 퍼플렉서티 105.08
# | 에폭 4 |  반복 321 / 1327 | 시간 14120[s] | 퍼플렉서티 84.56
# | 에폭 4 |  반복 341 / 1327 | 시간 14131[s] | 퍼플렉서티 100.28
# | 에폭 4 |  반복 361 / 1327 | 시간 14152[s] | 퍼플렉서티 129.78
# | 에폭 4 |  반복 381 / 1327 | 시간 14171[s] | 퍼플렉서티 97.47
# | 에폭 4 |  반복 401 / 1327 | 시간 14195[s] | 퍼플렉서티 111.23
# | 에폭 4 |  반복 421 / 1327 | 시간 14217[s] | 퍼플렉서티 96.26
# | 에폭 4 |  반복 441 / 1327 | 시간 14237[s] | 퍼플렉서티 104.26
# | 에폭 4 |  반복 461 / 1327 | 시간 14258[s] | 퍼플렉서티 101.16
# | 에폭 4 |  반복 481 / 1327 | 시간 14279[s] | 퍼플렉서티 103.78
# | 에폭 4 |  반복 501 / 1327 | 시간 14301[s] | 퍼플렉서티 109.38
# | 에폭 4 |  반복 521 / 1327 | 시간 14322[s] | 퍼플렉서티 116.56
# | 에폭 4 |  반복 541 / 1327 | 시간 14342[s] | 퍼플렉서티 113.04
# | 에폭 4 |  반복 561 / 1327 | 시간 14362[s] | 퍼플렉서티 103.27
# | 에폭 4 |  반복 581 / 1327 | 시간 14388[s] | 퍼플렉서티 89.91
# | 에폭 4 |  반복 601 / 1327 | 시간 14409[s] | 퍼플렉서티 128.22
# | 에폭 4 |  반복 621 / 1327 | 시간 14429[s] | 퍼플렉서티 124.03
# | 에폭 4 |  반복 641 / 1327 | 시간 14448[s] | 퍼플렉서티 112.42
# | 에폭 4 |  반복 661 / 1327 | 시간 14471[s] | 퍼플렉서티 104.14
# | 에폭 4 |  반복 681 / 1327 | 시간 14490[s] | 퍼플렉서티 85.85
# | 에폭 4 |  반복 701 / 1327 | 시간 14514[s] | 퍼플렉서티 103.47
# | 에폭 4 |  반복 721 / 1327 | 시간 14534[s] | 퍼플렉서티 109.71
# | 에폭 4 |  반복 741 / 1327 | 시간 14554[s] | 퍼플렉서티 96.11
# | 에폭 4 |  반복 761 / 1327 | 시간 14574[s] | 퍼플렉서티 87.73
# | 에폭 4 |  반복 781 / 1327 | 시간 14595[s] | 퍼플렉서티 87.85
# | 에폭 4 |  반복 801 / 1327 | 시간 14615[s] | 퍼플렉서티 99.09
# | 에폭 4 |  반복 821 / 1327 | 시간 14635[s] | 퍼플렉서티 102.52
# | 에폭 4 |  반복 841 / 1327 | 시간 14656[s] | 퍼플렉서티 98.34
# | 에폭 4 |  반복 861 / 1327 | 시간 14678[s] | 퍼플렉서티 105.49
# | 에폭 4 |  반복 881 / 1327 | 시간 14701[s] | 퍼플렉서티 92.29
# | 에폭 4 |  반복 901 / 1327 | 시간 14721[s] | 퍼플렉서티 115.78
# | 에폭 4 |  반복 921 / 1327 | 시간 14740[s] | 퍼플렉서티 103.62
# | 에폭 4 |  반복 941 / 1327 | 시간 14758[s] | 퍼플렉서티 112.92
# | 에폭 4 |  반복 961 / 1327 | 시간 14777[s] | 퍼플렉서티 112.62
# | 에폭 4 |  반복 981 / 1327 | 시간 14795[s] | 퍼플렉서티 108.56
# | 에폭 4 |  반복 1001 / 1327 | 시간 14815[s] | 퍼플렉서티 98.28
# | 에폭 4 |  반복 1021 / 1327 | 시간 14833[s] | 퍼플렉서티 113.48
# | 에폭 4 |  반복 1041 / 1327 | 시간 14852[s] | 퍼플렉서티 103.35
# | 에폭 4 |  반복 1061 / 1327 | 시간 14869[s] | 퍼플렉서티 89.28
# | 에폭 4 |  반복 1081 / 1327 | 시간 14888[s] | 퍼플렉서티 79.82
# | 에폭 4 |  반복 1101 / 1327 | 시간 14907[s] | 퍼플렉서티 81.48
# | 에폭 4 |  반복 1121 / 1327 | 시간 14926[s] | 퍼플렉서티 104.79
# | 에폭 4 |  반복 1141 / 1327 | 시간 14945[s] | 퍼플렉서티 100.28
# | 에폭 4 |  반복 1161 / 1327 | 시간 14964[s] | 퍼플렉서티 92.39
# | 에폭 4 |  반복 1181 / 1327 | 시간 14983[s] | 퍼플렉서티 97.24
# | 에폭 4 |  반복 1201 / 1327 | 시간 15003[s] | 퍼플렉서티 83.20
# | 에폭 4 |  반복 1221 / 1327 | 시간 15021[s] | 퍼플렉서티 76.48
# | 에폭 4 |  반복 1241 / 1327 | 시간 15040[s] | 퍼플렉서티 92.77
# | 에폭 4 |  반복 1261 / 1327 | 시간 15058[s] | 퍼플렉서티 94.28
# | 에폭 4 |  반복 1281 / 1327 | 시간 15076[s] | 퍼플렉서티 90.30
# | 에폭 4 |  반복 1301 / 1327 | 시간 15096[s] | 퍼플렉서티 110.93
# | 에폭 4 |  반복 1321 / 1327 | 시간 15115[s] | 퍼플렉서티 110.61
# 퍼플렉서티 평가 중 ...
# 234 / 235
# 테스트 퍼플렉서티:  135.24379266685662

# %% [markdown]
# 위의 실험에서 총 4에폭(1327*4회)의 학습을 수행하는데, 퍼플렉서티가 낮아져서 최종적으로 100에 근접하게 된다.(137정도, 하지만 2017기준 60까지니까 아직 한참 남았다.)

# %%
# coding: utf-8
import sys
sys.path.append('..')
from common.time_layers import *
from common.np import *  # import numpy as np
from common.base_model import BaseModel


class BetterRnnlm(BaseModel):
    '''
     LSTM 계층을 2개 사용하고 각 층에 드롭아웃을 적용한 모델이다.
     아래 [1]에서 제안한 모델을 기초로 하였고, [2]와 [3]의 가중치 공유(weight tying)를 적용했다.
     [1] Recurrent Neural Network Regularization (https://arxiv.org/abs/1409.2329)
     [2] Using the Output Embedding to Improve Language Models (https://arxiv.org/abs/1608.05859)
     [3] Tying Word Vectors and Word Classifiers (https://arxiv.org/pdf/1611.01462.pdf)
    '''
    def __init__(self, vocab_size=10000, wordvec_size=650,
                 hidden_size=650, dropout_ratio=0.5):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx1 = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh1 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b1 = np.zeros(4 * H).astype('f')
        lstm_Wx2 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_Wh2 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b2 = np.zeros(4 * H).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.layers = [
            TimeEmbedding(embed_W),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx1, lstm_Wh1, lstm_b1, stateful=True),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx2, lstm_Wh2, lstm_b2, stateful=True),
            TimeDropout(dropout_ratio),
            TimeAffine(embed_W.T, affine_b)  # weight tying!!
        ]
        # 위의 layers에서 개선이 들어가는 부분이다.
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layers = [self.layers[2], self.layers[4]]
        self.drop_layers = [self.layers[1], self.layers[3], self.layers[5]]

        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def predict(self, xs, train_flg=False):
        for layer in self.drop_layers:
            layer.train_flg = train_flg

        for layer in self.layers:
            xs = layer.forward(xs)
        return xs

    def forward(self, xs, ts, train_flg=True):
        score = self.predict(xs, train_flg)
        loss = self.loss_layer.forward(score, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        for layer in self.lstm_layers:
            layer.reset_state()

# %%
# coding: utf-8
import sys
sys.path.append('..')
from common import config
# GPU에서 실행하려면 아래 주석을 해제하세요(CuPy 필요).
# ==============================================
# config.GPU = True
# ==============================================
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity, to_gpu
from dataset import ptb


# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 650
hidden_size = 650
time_size = 35
lr = 20.0
max_epoch = 40
max_grad = 0.25
dropout = 0.5

# 학습 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_val, _, _ = ptb.load_data('val')
corpus_test, _, _ = ptb.load_data('test')

if config.GPU:
    corpus = to_gpu(corpus)
    corpus_val = to_gpu(corpus_val)
    corpus_test = to_gpu(corpus_test)

vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

model = BetterRnnlm(vocab_size, wordvec_size, hidden_size, dropout)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

best_ppl = float('inf')
for epoch in range(max_epoch):
    trainer.fit(xs, ts, max_epoch=1, batch_size=batch_size,
                time_size=time_size, max_grad=max_grad)

    model.reset_state()
    ppl = eval_perplexity(model, corpus_val)
    print('검증 퍼플렉서티: ', ppl)

    # 아래 best_ppl보다 낮으면 학습률을 줄여서 학습하게 설정을 한다.
    if best_ppl > ppl:
        best_ppl = ppl
        model.save_params()
    else:
        lr /= 4.0
        optimizer.lr = lr

    model.reset_state()
    print('-' * 50)


# 테스트 데이터로 평가
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('테스트 퍼플렉서티: ', ppl_test)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-e595b37cb59f> in <module>
#      11 from common.util import eval_perplexity, to_gpu
#      12 from dataset import ptb
# ---> 13 from better_rnnlm import BetterRnnlm
#      14
#      15
#
# ModuleNotFoundError: No module named 'better_rnnlm'
